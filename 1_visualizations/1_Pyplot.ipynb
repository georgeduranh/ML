# %% [markdown]
# <a href="https://colab.research.google.com/github/georgeduranh/ML/blob/main/1_visualizations/1_Pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5, 11)
y = x**2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, 'ro')
plt.show()

# %%
plt.plot(x,y, 'rs-')
plt.show()

# %%
plt.plot(x,y, 'yD:')
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()
